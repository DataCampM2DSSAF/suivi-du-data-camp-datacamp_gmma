# %% [markdown]
# # Settings

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import math

# %% [markdown]
# # Loading the data

# %%
sample_submission = pd.read_csv("C:/Users/odeli/Desktop/dataCamp_data/sample_submission.csv")
test = pd.read_csv("C:/Users/odeli/Desktop/dataCamp_data/test.csv")
specs = pd.read_csv("C:/Users/odeli/Desktop/dataCamp_data/specs.csv")
train_labels = pd.read_csv("C:/Users/odeli/Desktop/dataCamp_data/train_labels.csv")
train = pd.read_csv("C:/Users/odeli/Desktop/dataCamp_data/train.csv")

# %%
print('Shapes:\n - train: ', np.shape(train), '\n - train_labels: ',np.shape(train_labels), '\n - test: ',np.shape(test), '\n - specs: ',np.shape(specs), '\n - sample_submission: ',np.shape(sample_submission))
# Out:
# Shapes:
#  - train:  (11341042, 11)
#  - train_labels:  (17690, 7)
#  - test:  (1156414, 11)
#  - specs:  (386, 3)
#  - sample_submission:  (1000, 2)

# %% [markdown]
# ## Making labels

# %% [markdown]
# The first very important thing to do is to create the labels.
# As we said the right information is contained in the event_data column.
# This column is a dictionary with a variable size for each line.

# %% [markdown]
# Organisation of the information recorded by the application:
#     * When a child downloads the app an id is created: id_installation
#     * When he starts playing a game an other id is created: game_session
#     * Inside a game_session many things can be done by the gamer. Every event has its own id: event_id. The different possible events are caracterized by a code contained in the event_code column.
# The only useful events to build the labels are the last ones in a game session: they correspond to the succes or the failure of the game in a given game_session. The corrresponding event_code is 4100 for 4 of the 5 games and 4110 for the last one (Bird Measurer).

# %%
def get_accuracy(data):
    """
    input: data
    output: data_labels for each of the 5 games
    """
    
    df = pd.DataFrame()
    
    games = ['Bird Measurer', 'Cart Balancer', 'Cauldron Filler', 'Chest Sorter', 'Mushroom Sorter']
    
    # Loop on the 5 games
    for game in games:
        tmp = data[data['title'].str.contains(game)]
        
        # Filter the last event : 4110/4100 (code)
        if game == 'Bird Measurer':
            tmp = tmp[(tmp['event_code'] == 4110)]#| (tmp['event_code'] == 4100)]
        else:
            tmp = tmp[tmp['event_code'] == 4100]
    
        # num_correct and num_incorrect
        correct = ["NA" for i in range(np.shape(tmp)[0])]
        incorrect = ["NA" for i in range(np.shape(tmp)[0])]
        for i in range(np.shape(tmp)[0]):
            if ('correct":false' in tmp.loc[tmp.index[i], 'event_data']):
                correct[i] = 0
                incorrect[i] = 1
            elif ('correct":true' in tmp.loc[tmp.index[i], 'event_data']):
                correct[i] = 1
                incorrect[i] = 0
            else:
                correct[i] = 'NA'
                incorrect[i] = 'NA'
        tmp['num_correct'] = correct
        tmp['num_incorrect'] = incorrect
        tmp = pd.DataFrame(tmp.groupby(('installation_id','game_session','title')).sum())
            
        # accuracy
        accuracy = tmp['num_correct'] / (tmp['num_correct'] + tmp['num_incorrect'])
        tmp['accuracy'] = accuracy

        # accuracy_group
        tmp["accuracy_group"] = tmp["accuracy"].apply(lambda x: 0 if x==0 else (1 if x<0.5 else (2 if x<0.9 else 3)))
        df = pd.concat([df, tmp])
        
    df = df.reset_index()[['game_session','installation_id','title','num_correct','num_incorrect','accuracy','accuracy_group']]
    return(df)

# %%
my_train_labels = get_accuracy(train)
# Out:
# C:\Users\odeli\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.

# %%
np.shape(train_labels), np.shape(my_train_labels)
# Out:
# ((17690, 7), (17690, 7))

# %%
np.shape(my_train_labels), np.shape(train_labels)
# Out:
# ((17692, 7), (17690, 7))

# %% [markdown]
# ## Trucation of the train data

# %% [markdown]
# In this section we wrote a function that troncate data from the train in rder to reproduce the stucture of the test to be able to make predictions.
# To truncate the data (train) we used 4 methods:
#     * 'random : For each installation_id, randomly choose an assessment and truncate the data after the begining of this assessement.
#     * 'first' : For each installation_id truncate after one assessment
#     * 'last' : For each installation_id truncate right before the last assessment
#     * 'proportion' : Fix a proportion of assessment to keep and troncate the rest of the data

# %% [markdown]
# ### Removing the id without assessment

# %%
no_assess_id = []
unique_id = np.unique(train['installation_id'])
for id in unique_id:
        test_id = train[train['installation_id'] == id]
        n = test_id[(test_id['type']=='Assessment') & (test_id['event_code'] == 2000)].count()[0] #nombre d'assessment commencés
        if n==0: no_assess_id.append(id)
        if(len(no_assess_id)%1000 == 0): print(len(no_assess_id))

# %%
def truncate_data(data, how='random'):
    """
    Inputs:
        data : DataFrame in the shape of train.
        how : string. Method of truncation used (default:'random', other choices: 'first', 'last', 'proportion').
    Output:
        new_data : DataFrame. data where data is truncated from a given assessment.
    """
    num_col_type = 9
    num_col_ecode = 6
    
    print('Selecting unique installation_id in the data')
    unique_id = np.unique(data['installation_id'])
    print('Done !')
    
    new_data = pd.DataFrame(columns = data.columns)
    
    
    print('Truncation of the data')
    
    for id in unique_id:
        print('installation_id', id)
        test_id = data[data['installation_id'] == id]
        n = test_id[(test_id['type']=='Assessment') & (test_id['event_code'] == 2000)].count()[0] #nombre d'assessment commencés
        if n!=0:
            if how == 'random': ass_trunc = randint(1,n)
            elif how == 'first': ass_trunc = 1
            elif how == 'last': ass_trunc = n
            idx = 0 # nombre d'assessment commencés
            idx_tmp = 0 # numéro de la ligne courante
            while(idx < ass_trunc):
                if((test_id.iloc[idx_tmp, num_col_type]== 'Assessment') & (test_id.iloc[idx_tmp, num_col_ecode] == 2000)):
                    idx += 1
                idx_tmp += 1
            new_data = pd.concat([new_data, test_id[0:idx_tmp]])
            print('current data id shape', np.shape(test_id[0:idx_tmp]))
            print('new data shape', np.shape(new_data))
    return(new_data)

# %%
import time

start_time = time.time()

new_data = truncate_data(train)

print("Temps d execution : %s secondes ---" % (time.time() - start_time))
# Out:
# Selecting unique installation_id in the data
# Done !
# Truncation of the data
# installation_id 0001e90f
# installation_id 000447c4
# installation_id 0006a69f
# current data id shape (648, 11)
# new data shape (648, 11)
# installation_id 0006c192
# current data id shape (1899, 11)
# new data shape (2547, 11)
# installation_id 0009a5a9
# installation_id 0011edc8
# installation_id 00129856
# current data id shape (4, 11)
# new data shape (2551, 11)
# installation_id 0016b7cc
# installation_id 00195df7
# installation_id 001d0ed0
# current data id shape (7, 11)
# new data shape (2558, 11)
# installation_id 002114ae
# installation_id 00219589
# installation_id 00225f67
# current data id shape (605, 11)
# new data shape (3163, 11)
# installation_id 00279ac5
# current data id shape (2501, 11)
# new data shape (5664, 11)
# installation_id 002c8bae
# installation_id 002db7e3
# current data id shape (2536, 11)
# new data shape (8200, 11)
# installation_id 003372b0
# current data id shape (190, 11)
# new data shape (8390, 11)
# installation_id 0034471d
# installation_id 0038b87c
# installation_id 003a6dff
# installation_id 004adee1
# installation_id 004c2091
# current data id shape (149, 11)
# new data shape (8539, 11)
# installation_id 0050f7a8
# installation_id 0051064f
# installation_id 00511b72
# installation_id 0052394a
# installation_id 00524526
# installation_id 005ccc35
# installation_id 00634433
# current data id shape (105, 11)
# new data shape (8644, 11)
# installation_id 00651949
# installation_id 00667b88
# current data id shape (433, 11)
# new data shape (9077, 11)
# installation_id 00681329
# installation_id 00691033
# current data id shape (1895, 11)
# new data shape (10972, 11)
# installation_id 006bfa41
# installation_id 006e425d
# installation_id 00717020
# installation_id 0074b727
# installation_id 007836c4
# installation_id 0080845b
# installation_id 0082ac42
# installation_id 008c0e11
# installation_id 00912a40
# installation_id 009412f0
# installation_id 00981237
# installation_id 009b3df7
# installation_id 00a0dbeb
# current data id shape (191, 11)
# new data shape (11163, 11)
# installation_id 00a2c5a2
# installation_id 00a5117e
# installation_id 00a53963
# current data id shape (2, 11)
# new data shape (11165, 11)
# installation_id 00a54d56
# installation_id 00a68ef8
# installation_id 00a803f0
# installation_id 00a915d6
# installation_id 00acad3b
# installation_id 00ad158e
# current data id shape (854, 11)
# new data shape (12019, 11)
# installation_id 00ae9d04
# current data id shape (213, 11)
# new data shape (12232, 11)
# installation_id 00b46e37
# installation_id 00b7e13f
# installation_id 00b80069
# installation_id 00b9d8e6
# current data id shape (64, 11)
# new data shape (12296, 11)
# installation_id 00c1f513
# installation_id 00c47566
# installation_id 00c53335
# installation_id 00c5c47a
# installation_id 00c7368f
# installation_id 00c8ccc2
# installation_id 00ca1db4
# installation_id 00cef781
# current data id shape (162, 11)
# new data shape (12458, 11)
# installation_id 00d2576a
# current data id shape (2776, 11)
# new data shape (15234, 11)
# installation_id 00d62e8d
# installation_id 00d8a6f2
# installation_id 00dca92b
# installation_id 00def727
# installation_id 00e14f48
# installation_id 00e17272
# current data id shape (473, 11)
# new data shape (15707, 11)
# installation_id 00e536bf
# current data id shape (1593, 11)
# new data shape (17300, 11)
# installation_id 00ef784f
# installation_id 00f32308
# installation_id 00f502d7
# installation_id 00f76edc
# installation_id 00fa8681
# current data id shape (1994, 11)
# new data shape (19294, 11)
# installation_id 00fc1dde
# installation_id 00fc65b6
# current data id shape (5657, 11)
# new data shape (24951, 11)
# installation_id 01023cbc
# installation_id 01031768
# installation_id 0103b0b4
# installation_id 0103e38e
# installation_id 010bc1d5
# current data id shape (111, 11)
# new data shape (25062, 11)
# installation_id 010c6411
# installation_id 0111e876
# installation_id 01120f12
# current data id shape (494, 11)
# new data shape (25556, 11)
# installation_id 01151be1
# installation_id 011725f9
# installation_id 011804aa
# installation_id 0118a6a8
# installation_id 0119785b
# installation_id 01380088
# current data id shape (116, 11)
# new data shape (25672, 11)
# installation_id 0140c2eb
# installation_id 0142a0c8
# installation_id 014ba422
# installation_id 014ef504
# current data id shape (2, 11)
# new data shape (25674, 11)
# installation_id 014fafb4
# installation_id 0150216b
# installation_id 0153c957
# current data id shape (1467, 11)
# new data shape (27141, 11)
# installation_id 01548e41
# installation_id 0155dd86
# current data id shape (546, 11)
# new data shape (27687, 11)
# installation_id 015776b4
# current data id shape (1814, 11)
# new data shape (29501, 11)
# installation_id 01582211
# current data id shape (1512, 11)
# new data shape (31013, 11)
# installation_id 0160e7c5
# current data id shape (301, 11)
# new data shape (31314, 11)
# installation_id 01693919
# installation_id 016b4928
# installation_id 016d81f7
# installation_id 01773ea2
# installation_id 0177657f
# installation_id 017a0220
# installation_id 017dc73e
# installation_id 017fba52
# installation_id 01825124
# current data id shape (1200, 11)
# new data shape (32514, 11)
# installation_id 0190db45
# installation_id 019e0632
# installation_id 01a0c5ac
# current data id shape (702, 11)
# new data shape (33216, 11)
# installation_id 01a2039d
# installation_id 01a8ea81
# installation_id 01b5747a
# installation_id 01b58d19
# current data id shape (187, 11)
# new data shape (33403, 11)
# installation_id 01b82b95
# installation_id 01b8fb17
# installation_id 01bdd720
# current data id shape (409, 11)
# new data shape (33812, 11)
# installation_id 01bfa3bd
# installation_id 01c06310
# current data id shape (186, 11)
# new data shape (33998, 11)
# installation_id 01c85524
# installation_id 01cc53f3
# current data id shape (206, 11)
# new data shape (34204, 11)
# installation_id 01d0c251
# installation_id 01d24159
# installation_id 01d26280
# installation_id 01d5d65f
# installation_id 01d5e1f5
# current data id shape (312, 11)
# new data shape (34516, 11)
# installation_id 01d7234e
# installation_id 01ebdc56
# installation_id 01eff8ad
# installation_id 01f069eb
# installation_id 01f71702
# current data id shape (142, 11)
# new data shape (34658, 11)
# installation_id 01faa4bf
# current data id shape (626, 11)
# new data shape (35284, 11)
# installation_id 01fc919f
# installation_id 01fd12c0
# installation_id 020150f3
# installation_id 0201e248
# installation_id 020903df
# installation_id 021baee9
# installation_id 0220cc1c
# installation_id 022183ab
# current data id shape (2506, 11)
# new data shape (37790, 11)
# installation_id 02243b7f
# installation_id 022838e5
# installation_id 022d38c2
# installation_id 02309654
# installation_id 0231a9fc
# installation_id 0235fe9a
# current data id shape (1212, 11)
# new data shape (39002, 11)
# installation_id 023c4bcb
# current data id shape (716, 11)
# new data shape (39718, 11)
# installation_id 023d003b
# installation_id 023de989
# installation_id 023dec63
# installation_id 0240420f
# installation_id 02412121
# installation_id 0242ae71
# installation_id 02490b06
# current data id shape (2, 11)
# new data shape (39720, 11)
# installation_id 0249ebd3
# installation_id 024b5c80
# installation_id 024d9097
# installation_id 0255647b
# installation_id 025be69b
# installation_id 026035e9
# current data id shape (1526, 11)
# new data shape (41246, 11)
# installation_id 0261d6f2
# installation_id 0263a60c
# installation_id 026a2671
# installation_id 026b6aa0
# installation_id 026c7f47
# installation_id 026e3733
# current data id shape (178, 11)
# new data shape (41424, 11)
# installation_id 027b3c4c
# current data id shape (885, 11)
# new data shape (42309, 11)
# installation_id 027e543d
# installation_id 0281f6bf
# current data id shape (365, 11)
# new data shape (42674, 11)
# installation_id 02875dc2
# current data id shape (181, 11)
# new data shape (42855, 11)
# installation_id 028cf0e1
# installation_id 0293ae74
# current data id shape (220, 11)
# new data shape (43075, 11)
# installation_id 0299fe2d
# installation_id 029fff6f
# installation_id 02a81cf3
# installation_id 02aa515f
# current data id shape (140, 11)
# new data shape (43215, 11)
# installation_id 02b1fab4
# current data id shape (403, 11)
# new data shape (43618, 11)
# installation_id 02baf64c
# installation_id 02c0f045
# installation_id 02c52df7
# installation_id 02c975bc
# current data id shape (256, 11)
# new data shape (43874, 11)
# installation_id 02cc511e
# installation_id 02cdd48e
# current data id shape (140, 11)
# new data shape (44014, 11)
# installation_id 02cdfffd
# current data id shape (1441, 11)
# new data shape (45455, 11)
# installation_id 02d078b7
# current data id shape (40, 11)
# new data shape (45495, 11)
# installation_id 02d8be27
# installation_id 02d941bc
# installation_id 02dea012
# installation_id 02e76f43
# current data id shape (99, 11)
# new data shape (45594, 11)
# installation_id 02e9933e
# installation_id 02ec71ba
# installation_id 02eea537
# installation_id 02f2f9e3
# installation_id 02f5e2ca
# installation_id 02f6deb0
# installation_id 02fcc8bb
# installation_id 0303dfb9
# installation_id 03051b16
# installation_id 030c7e8d
# installation_id 030fce10
# installation_id 0310be7c
# installation_id 03159dfa
# installation_id 0316787c
# installation_id 031af3b8
# current data id shape (543, 11)
# new data shape (46137, 11)
# installation_id 031d2723
# installation_id 0328fc8f
# current data id shape (1909, 11)
# new data shape (48046, 11)
# installation_id 032ae6c8
# installation_id 0338becb
# installation_id 033eb4f6
# installation_id 03401e19
# current data id shape (2031, 11)
# new data shape (50077, 11)
# installation_id 0340b6b4
# installation_id 0341fa66
# installation_id 03425c89
# installation_id 034f357a
# installation_id 03560e11
# current data id shape (643, 11)
# new data shape (50720, 11)
# installation_id 03595697
# installation_id 0363c36f
# installation_id 036911d6
# installation_id 036e66f5
# installation_id 036efa1c
# installation_id 03785eca
# installation_id 037d40b3
# installation_id 03851035
# installation_id 0385f862
# installation_id 0387bb33
# installation_id 0387fb45
# installation_id 038bda7c
# installation_id 039137c7
# installation_id 03957682
# current data id shape (1110, 11)
# new data shape (51830, 11)
# installation_id 03981b27
# installation_id 039e4ac7
# current data id shape (1229, 11)
# new data shape (53059, 11)
# installation_id 03a5b006
# current data id shape (1042, 11)
# new data shape (54101, 11)
# installation_id 03a9fbc5
# installation_id 03b6031b
# current data id shape (180, 11)
# new data shape (54281, 11)
# installation_id 03b6fabf
# installation_id 03b74be5
# current data id shape (279, 11)
# new data shape (54560, 11)
# installation_id 03b76df6
# installation_id 03b7a5f4
# installation_id 03b8f942
# installation_id 03b9d002
# installation_id 03bf2563
# current data id shape (4468, 11)
# new data shape (59028, 11)
# installation_id 03c1ebae
# installation_id 03c5998d
# current data id shape (4, 11)
# new data shape (59032, 11)
# installation_id 03cd458d
# current data id shape (1, 11)
# new data shape (59033, 11)
# installation_id 03d15b59
# current data id shape (216, 11)
# new data shape (59249, 11)
# installation_id 03d9f11a
# installation_id 03e1c8cb
# installation_id 03e38765
# current data id shape (211, 11)
# new data shape (59460, 11)
# installation_id 03e52e82
# installation_id 03ef66b7
# installation_id 03f4ab64
# installation_id 03f548cc
# installation_id 03f89040
# current data id shape (602, 11)
# new data shape (60062, 11)
# installation_id 03fd7437
# installation_id 040ad22e
# installation_id 040dbdbe
# current data id shape (72, 11)
# new data shape (60134, 11)
# installation_id 040f7682
# installation_id 0413ae4a
# current data id shape (796, 11)
# new data shape (60930, 11)
# installation_id 041607d7
# installation_id 042043ab
# installation_id 04226e51
# installation_id 042285c4
# installation_id 04240fb1
# current data id shape (95, 11)
# new data shape (61025, 11)
# installation_id 042711d1
# installation_id 0428c915
# installation_id 0429e1ff
# current data id shape (4056, 11)
# new data shape (65081, 11)
# installation_id 043177d7
# installation_id 0433afd5
# installation_id 0434613b
# current data id shape (215, 11)
# new data shape (65296, 11)
# installation_id 0439347b
# installation_id 043baf9e
# installation_id 043e7f32
# current data id shape (284, 11)
# new data shape (65580, 11)
# installation_id 043ed5a9
# installation_id 044085ab
# installation_id 0441baf0
# installation_id 0444f6ba
# installation_id 044c75b4
# installation_id 0454e835
# installation_id 0455dc92
# installation_id 045e87e0
# installation_id 04607075
# installation_id 04616599
# current data id shape (584, 11)
# new data shape (66164, 11)
# installation_id 046234c2
# current data id shape (130, 11)
# new data shape (66294, 11)
# installation_id 046c130d
# installation_id 04751556
# installation_id 047554a7
# current data id shape (31, 11)
# new data shape (66325, 11)
# installation_id 0478b042
# current data id shape (667, 11)
# new data shape (66992, 11)
# installation_id 0487c587
# installation_id 0487ec4a
# installation_id 04907bff
# installation_id 049397c7
# installation_id 04963bef
# current data id shape (347, 11)
# new data shape (67339, 11)
# installation_id 049890cb
# installation_id 049bd152
# installation_id 04a1f9aa
# installation_id 04a41e65
# installation_id 04a57775
# current data id shape (556, 11)
# new data shape (67895, 11)
# installation_id 04a5927d
# current data id shape (9448, 11)
# new data shape (77343, 11)
# installation_id 04a7dc17
# installation_id 04b97553
# installation_id 04bb186b
# installation_id 04c612fd
# current data id shape (1991, 11)
# new data shape (79334, 11)
# installation_id 04c79f80
# installation_id 04c8f3f9
# installation_id 04d56231
# installation_id 04d7401f
# installation_id 04d77ef2
# current data id shape (307, 11)
# new data shape (79641, 11)
# installation_id 04dc3326
# installation_id 04de2aae
# current data id shape (147, 11)
# new data shape (79788, 11)
# installation_id 04e09a61
# installation_id 04e2712b
# current data id shape (6230, 11)
# new data shape (86018, 11)
# installation_id 04e3c0d4
# installation_id 04e3e5f5
# installation_id 04f2cf8f
# current data id shape (756, 11)
# new data shape (86774, 11)
# installation_id 04f579d6
# installation_id 04f621c8
# installation_id 04f67ebd
# installation_id 04f82e17
# installation_id 04f8b246
# current data id shape (224, 11)
# new data shape (86998, 11)
# installation_id 04fa906f
# current data id shape (582, 11)
# new data shape (87580, 11)
# installation_id 04fa968e
# installation_id 04faab66
# installation_id 04fbee62
# current data id shape (104, 11)
# new data shape (87684, 11)
# installation_id 04fc5377
# installation_id 0500677c
# installation_id 0503d830
# current data id shape (941, 11)
# new data shape (88625, 11)
# installation_id 05047409
# current data id shape (4636, 11)
# new data shape (93261, 11)
# installation_id 0506f104
# current data id shape (238, 11)
# new data shape (93499, 11)
# installation_id 050b5e42
# installation_id 050bd7ba
# installation_id 050f6d04
# current data id shape (991, 11)
# new data shape (94490, 11)
# installation_id 051007e6
# installation_id 0511145e
# installation_id 05118f81
# current data id shape (3417, 11)
# new data shape (97907, 11)
# installation_id 051320ea
# installation_id 051794c4
# current data id shape (4603, 11)
# new data shape (102510, 11)
# installation_id 05181b10
# installation_id 05184d32
# installation_id 051bc5a5
# current data id shape (268, 11)
# new data shape (102778, 11)
# installation_id 05239f3f
# current data id shape (370, 11)
# new data shape (103148, 11)
# installation_id 05262f40
# installation_id 05291f1e
# installation_id 0529d958
# installation_id 052aacaa
# installation_id 052d2fe2
# installation_id 05309abe
# current data id shape (539, 11)
# new data shape (103687, 11)
# installation_id 053208d7
# installation_id 05376756
# installation_id 053e6353
# current data id shape (569, 11)
# new data shape (104256, 11)
# installation_id 05429db7
# installation_id 054acf79
# installation_id 054c3d46
# installation_id 054dd1d4
# installation_id 0559c200
# installation_id 055a7aae
# installation_id 055f7e60
# installation_id 055f9c7a
# installation_id 056017d7
# installation_id 0569417e
# installation_id 0569b29c
# installation_id 05714df0
# installation_id 0577d57c
# installation_id 057c3f4a
# installation_id 057d6eb0
# installation_id 057dae0b
# installation_id 057e7630
# installation_id 05821636
# installation_id 0582778c
# installation_id 0583693e
# current data id shape (3606, 11)
# new data shape (107862, 11)
# installation_id 0588f7e6
# installation_id 05899550
# installation_id 058dddc5
# installation_id 058f4baf
# installation_id 058fbe5b
# current data id shape (59, 11)
# new data shape (107921, 11)
# installation_id 05924fdb
# installation_id 05928de6
# installation_id 0593049e
# installation_id 05954d47
# current data id shape (1364, 11)
# new data shape (109285, 11)
# installation_id 05a3ae61
# current data id shape (1242, 11)
# new data shape (110527, 11)
# installation_id 05a5be98
# installation_id 05a6a04e
# installation_id 05a78868
# installation_id 05a86ccd
# installation_id 05aaa5c9
# current data id shape (627, 11)
# new data shape (111154, 11)
# installation_id 05aeb935
# installation_id 05afe83e
# installation_id 05b198a5
# current data id shape (527, 11)
# new data shape (111681, 11)
# installation_id 05b3a238
# installation_id 05b79972
# current data id shape (367, 11)
# new data shape (112048, 11)
# installation_id 05b93ff2
# installation_id 05bc97c3
# current data id shape (215, 11)
# new data shape (112263, 11)
# installation_id 05bdd84c
# installation_id 05c5eec4
# installation_id 05ca87d5
# installation_id 05cb3137
# installation_id 05d361e3
# installation_id 05d7fdb9
# installation_id 05d87bdb
# installation_id 05dbd093
# installation_id 05e2c8cb
# installation_id 05ebaeb6
# installation_id 05f25d49
# installation_id 05f728b5
# installation_id 05f87622
# installation_id 05f9d07e
# installation_id 05fc08e8
# installation_id 0600b1c6
# installation_id 0607efb8
# current data id shape (943, 11)
# new data shape (113206, 11)
# installation_id 0609d006
# installation_id 061052f0
# installation_id 0612dea7
# installation_id 061750e7
# installation_id 0621634e
# installation_id 0622f6c0
# installation_id 06289c67
# installation_id 062ce0bf
# installation_id 06312d74
# installation_id 0633cad0
# current data id shape (311, 11)
# new data shape (113517, 11)
# installation_id 063405ff
# current data id shape (664, 11)
# new data shape (114181, 11)
# installation_id 06362232
# current data id shape (2602, 11)
# new data shape (116783, 11)
# installation_id 0638ea7b
# installation_id 063a472e
# installation_id 063a9341
# installation_id 063ab77a
# installation_id 063c67fc
# installation_id 063e3e02
# current data id shape (16445, 11)
# new data shape (133228, 11)
# installation_id 063fd8cc
# installation_id 0642544a
# current data id shape (509, 11)
# new data shape (133737, 11)
# installation_id 06435d15
# current data id shape (664, 11)
# new data shape (134401, 11)
# installation_id 0646a3b4
# installation_id 064afbe4
# installation_id 064c24c0
# current data id shape (2670, 11)
# new data shape (137071, 11)
# installation_id 064ce788
# installation_id 064e6507
# installation_id 0651e4e8
# installation_id 0658a78c
# installation_id 065ae9bd
# installation_id 065bafe3
# installation_id 065faf66
# installation_id 0666918b
# installation_id 06689531
# installation_id 0669c763
# installation_id 066a3611
# installation_id 066bea6e
# installation_id 066d3d74
# installation_id 0672cc38
# installation_id 067c962e
# installation_id 0688471f
# current data id shape (8, 11)
# new data shape (137079, 11)
# installation_id 06906111
# current data id shape (212, 11)
# new data shape (137291, 11)
# installation_id 069a05ed
# installation_id 069d6549
# installation_id 069df193
# installation_id 06a282f7
# installation_id 06a2eefc
# installation_id 06a6dea0
# current data id shape (545, 11)
# new data shape (137836, 11)
# installation_id 06ac12cb
# installation_id 06ba3f9a
# installation_id 06c1714a
# installation_id 06c45c67
# installation_id 06c523d8
# installation_id 06c7cb57
# installation_id 06c7ef38
# installation_id 06cb2c9f
# installation_id 06cd00ae
# installation_id 06cf17ad
# installation_id 06d28015
# current data id shape (6, 11)
# new data shape (137842, 11)
# installation_id 06dfbd2f
# installation_id 06e445f3
# installation_id 06e53b39
# installation_id 06e6a3e3
# current data id shape (551, 11)
# new data shape (138393, 11)
# installation_id 06e6ffda
# installation_id 06e7170d
# installation_id 06e959c2
# installation_id 06ec5303
# installation_id 06ee21c7
# installation_id 06ee96a3
# installation_id 06f12094
# current data id shape (1101, 11)
# new data shape (139494, 11)
# installation_id 06f731f4
# installation_id 06fbd7aa
# installation_id 06fe8a94
# installation_id 07020e30
# installation_id 0706d70d
# installation_id 070760a2
# installation_id 070cb1a9
# installation_id 070d7757
# installation_id 070f7668
# installation_id 0710f885
# installation_id 071232d5
# installation_id 071644cd
# installation_id 0717d843
# installation_id 07216b37
# installation_id 0722aacb
# installation_id 072a25ac
# current data id shape (9975, 11)
# new data shape (149469, 11)
# installation_id 072f3f32
# installation_id 07348c25
# installation_id 0736a515
# installation_id 07387a24
# installation_id 0743d3ee
# installation_id 074842c4
# installation_id 0749b2ba
# installation_id 074b4825
# current data id shape (346, 11)
# new data shape (149815, 11)
# installation_id 074d0b80
# installation_id 0751b910
# installation_id 07540cd1
# installation_id 07548db3
# installation_id 075cbae2
# current data id shape (1375, 11)
# new data shape (151190, 11)
# installation_id 07628b3c
# installation_id 0765886f
# installation_id 076b08db
# current data id shape (2238, 11)
# new data shape (153428, 11)
# installation_id 076cefe9
# installation_id 076d4ecd
# installation_id 077173b2
# current data id shape (1210, 11)
# new data shape (154638, 11)
# installation_id 07731248
# current data id shape (281, 11)
# new data shape (154919, 11)
# installation_id 077b3c9c
# current data id shape (708, 11)
# new data shape (155627, 11)
# installation_id 077b5a9f
# installation_id 0785ef54
# installation_id 07861450
# current data id shape (1428, 11)
# new data shape (157055, 11)
# installation_id 0787942b
# installation_id 078d4da1
# installation_id 07914dc8
# installation_id 079177d2
# installation_id 07921f07
# current data id shape (390, 11)
# new data shape (157445, 11)
# installation_id 079294ee
# current data id shape (7, 11)
# new data shape (157452, 11)
# installation_id 0793409e
# current data id shape (615, 11)
# new data shape (158067, 11)
# installation_id 0794f828
# installation_id 0799e1de
# installation_id 07a16fc4
# installation_id 07a5e808
# installation_id 07a80ed2
# installation_id 07ae5a97
# current data id shape (2094, 11)
# new data shape (160161, 11)
# installation_id 07aec451
# installation_id 07b3fc17
# current data id shape (382, 11)
# new data shape (160543, 11)
# installation_id 07b4f849
# installation_id 07b94636
# installation_id 07b9489e
# installation_id 07be824e
# current data id shape (554, 11)
# new data shape (161097, 11)
# installation_id 07c25408
# current data id shape (145, 11)
# new data shape (161242, 11)
# installation_id 07c7e8c2
# installation_id 07cc156e
# installation_id 07d0f052
# installation_id 07d60a38
# installation_id 07dabd51
# installation_id 07ebdf32
# installation_id 07ef08f9
# installation_id 07efaff2
# current data id shape (678, 11)
# new data shape (161920, 11)
# installation_id 07f5461f
# installation_id 08062502
# current data id shape (1, 11)
# new data shape (161921, 11)
# installation_id 0807821a
# installation_id 08097f17
# installation_id 080f9689
# current data id shape (6298, 11)
# new data shape (168219, 11)
# installation_id 08179779
# current data id shape (3, 11)
# new data shape (168222, 11)
# installation_id 0818ddc6
# installation_id 081bbd54
# installation_id 081cd85f
# installation_id 08243749
# installation_id 0825d960
# installation_id 0826382e
# installation_id 0827245b
# installation_id 08288457
# installation_id 0828cccc
# installation_id 0829e744
# installation_id 0832daa8
# installation_id 0835346c
# installation_id 0837bb14
# installation_id 083a2358
# installation_id 083ab2c5
# installation_id 0841d95c
# installation_id 0849d7b5
# installation_id 084b7810
# installation_id 084feb93
# installation_id 08506b98
# installation_id 08595abf
# installation_id 085cbfa4
# installation_id 086090c6
# installation_id 0861aefa
# installation_id 0864d9a2
# current data id shape (377, 11)
# new data shape (168599, 11)
# installation_id 0868f7b8
# installation_id 087adaeb
# installation_id 087e628d
# installation_id 08896e25
# installation_id 088caf6e
# current data id shape (81, 11)
# new data shape (168680, 11)
# installation_id 088e2f31
# installation_id 089189b0
# installation_id 08928b97
# installation_id 08987c08
# current data id shape (8188, 11)
# new data shape (176868, 11)
# installation_id 089fe078
# installation_id 08a47256
# current data id shape (162, 11)
# new data shape (177030, 11)
# installation_id 08a55396
# installation_id 08a6814c
# current data id shape (135, 11)
# new data shape (177165, 11)
# installation_id 08acfc52
# installation_id 08ad8e56
# installation_id 08af0425
# installation_id 08b12d1c
# installation_id 08b40c98
# installation_id 08b6f70e
# installation_id 08bd54d5
# installation_id 08be194a
# installation_id 08c7db4f
# installation_id 08d50b54
# current data id shape (1703, 11)
# new data shape (178868, 11)
# installation_id 08d889ac
# installation_id 08df1cd0
# current data id shape (570, 11)
# new data shape (179438, 11)
# installation_id 08df9f9c
# current data id shape (123, 11)
# new data shape (179561, 11)
# installation_id 08e1179d
# installation_id 08e2b1eb
# installation_id 08e325db
# installation_id 08e532dd
# installation_id 08e5c4e6
# current data id shape (382, 11)
# new data shape (179943, 11)
# installation_id 08ecc9b0
# installation_id 08eee52e
# current data id shape (764, 11)
# new data shape (180707, 11)
# installation_id 08f324ce
# installation_id 08f764c2
# installation_id 08f8813c
# current data id shape (3616, 11)
# new data shape (184323, 11)
# installation_id 08fb3557
# installation_id 0900347d
# installation_id 090039e2
# installation_id 09019816
# installation_id 0904996d
# installation_id 09054c48
# installation_id 090ede6c
# installation_id 090f9637
# installation_id 09145069
# installation_id 09159e3b
# installation_id 0917f697
# installation_id 0918babb
# current data id shape (724, 11)
# new data shape (185047, 11)
# installation_id 091a69a9
# installation_id 091ad6e3
# installation_id 091d51e8
# current data id shape (263, 11)
# new data shape (185310, 11)
# installation_id 091f80a9
# current data id shape (399, 11)
# new data shape (185709, 11)
# installation_id 09232fea
# installation_id 0925babb
# current data id shape (4252, 11)
# new data shape (189961, 11)
# installation_id 092691b2
# current data id shape (202, 11)
# new data shape (190163, 11)
# installation_id 09296168
# current data id shape (1770, 11)
# new data shape (191933, 11)
# installation_id 0929ce12
# installation_id 0938a8eb
# current data id shape (1, 11)
# new data shape (191934, 11)
# installation_id 093da0a5
# current data id shape (79, 11)
# new data shape (192013, 11)
# installation_id 093f923a
# installation_id 09437eec
# installation_id 09438458
# installation_id 0946474d
# current data id shape (67, 11)
# new data shape (192080, 11)
# installation_id 094ad5f8
# current data id shape (140, 11)
# new data shape (192220, 11)
# installation_id 094bf28e
# installation_id 09567b98
# installation_id 0958fa60
# installation_id 095d6cfe
# installation_id 0964d2ba
# installation_id 096af694
# installation_id 09724907
# installation_id 09733558
# installation_id 097432ca
# installation_id 0976c68d
# installation_id 097cea67
# installation_id 09846f3a
# installation_id 0986a4b3
# installation_id 098bed49
# installation_id 098e9715
# installation_id 098ee51f
# installation_id 099049a7
# installation_id 0994d04d
# installation_id 09992579
# installation_id 099a3ab8
# current data id shape (208, 11)
# new data shape (192428, 11)
# installation_id 099a50a0
# installation_id 099a6add
# current data id shape (212, 11)
# new data shape (192640, 11)
# installation_id 09a22787
# current data id shape (153, 11)
# new data shape (192793, 11)
# installation_id 09a57ab7
# installation_id 09b10dd1
# installation_id 09b3ed1f
# installation_id 09b92d3a
# installation_id 09b9d54d
# installation_id 09b9e85b
# installation_id 09bbf58e
# current data id shape (567, 11)
# new data shape (193360, 11)
# installation_id 09caaca9
# installation_id 09ce7996
# installation_id 09d4b5a0
# current data id shape (6, 11)
# new data shape (193366, 11)
# installation_id 09deccb9
# installation_id 09e154bd
# installation_id 09e6a55a
# installation_id 09e8f7b5
# installation_id 09ee8dd1
# installation_id 09f6ade3
# installation_id 09f91f9b
# installation_id 09fb0e32
# installation_id 09ffa409
# current data id shape (573, 11)
# new data shape (193939, 11)
# installation_id 0a0080e6
# installation_id 0a00abf7
# current data id shape (277, 11)
# new data shape (194216, 11)
# installation_id 0a014a54
# installation_id 0a0924bf
# installation_id 0a095781
# installation_id 0a0957ca
# current data id shape (144, 11)
# new data shape (194360, 11)
# installation_id 0a0b1178
# current data id shape (47, 11)
# new data shape (194407, 11)
# installation_id 0a0ce463
# installation_id 0a134a1b
# installation_id 0a14d90b
# installation_id 0a15f8b0
# installation_id 0a1d958f
# installation_id 0a2204aa
# installation_id 0a28896f
# installation_id 0a28a228
# installation_id 0a2bea41
# current data id shape (938, 11)
# new data shape (195345, 11)
# installation_id 0a2e33e1
# installation_id 0a313708
# current data id shape (4074, 11)
# new data shape (199419, 11)
# installation_id 0a31ae6b
# installation_id 0a38406d
# installation_id 0a386c5e
# current data id shape (498, 11)
# new data shape (199917, 11)
# installation_id 0a3a35da
# installation_id 0a3cfb75
# installation_id 0a3ed097
# installation_id 0a421672
# installation_id 0a45d619
# current data id shape (93, 11)
# new data shape (200010, 11)
# installation_id 0a497f04
# installation_id 0a559ddf
# installation_id 0a56fb9f
# installation_id 0a576823
# installation_id 0a5b321a
# installation_id 0a6f5e39
# installation_id 0a747a2e
# installation_id 0a74e242
# installation_id 0a7a5759
# installation_id 0a8190fb
# installation_id 0a84587b
# installation_id 0a892350
# installation_id 0a8cd5e5
# installation_id 0a90d04c
# current data id shape (6670, 11)
# new data shape (206680, 11)
# installation_id 0a925a62
# installation_id 0a9351a6
# installation_id 0a99112a
# installation_id 0a9fc1c7
# installation_id 0aa4652b
# installation_id 0aa73487
# installation_id 0aabcfea
# installation_id 0ab39a3b
# current data id shape (356, 11)
# new data shape (207036, 11)
# installation_id 0ab47d46
# installation_id 0abf579a
# installation_id 0ac5c953
# installation_id 0ad06153
# installation_id 0ad09cfd
# installation_id 0ad39397
# installation_id 0adb79e5
# installation_id 0adf7bc1
# installation_id 0ae537a9
# installation_id 0ae8bf05
# installation_id 0ae8c9fa
# installation_id 0aeb8c34
# installation_id 0af4eda8
# installation_id 0af52421
# current data id shape (292, 11)
# new data shape (207328, 11)
# installation_id 0af768cc
# installation_id 0afa42d5
# installation_id 0b07f4a1
# installation_id 0b09f7b2
# installation_id 0b0d7676
# installation_id 0b0dbf93
# current data id shape (738, 11)
# new data shape (208066, 11)
# installation_id 0b105ef6
# current data id shape (539, 11)
# new data shape (208605, 11)
# installation_id 0b1124fe
# installation_id 0b221698
# installation_id 0b2265a8
# installation_id 0b26b314
# installation_id 0b2f3606
# installation_id 0b2fe8e3
# current data id shape (172, 11)
# new data shape (208777, 11)
# installation_id 0b3a21f2
# installation_id 0b4148b8
# installation_id 0b446c3c
# installation_id 0b44ef54
# installation_id 0b4831c6
# installation_id 0b4a9342
# installation_id 0b4dc912
# installation_id 0b4ef042
# installation_id 0b51fa75
# current data id shape (91, 11)
# new data shape (208868, 11)
# installation_id 0b554988
# current data id shape (782, 11)
# new data shape (209650, 11)
# installation_id 0b5d46e6
# installation_id 0b5d4952
# installation_id 0b5efd86
# installation_id 0b615657
# installation_id 0b6d68e5
# current data id shape (333, 11)
# new data shape (209983, 11)
# installation_id 0b71f36c
# installation_id 0b7a0a24
# installation_id 0b7ad11d
# current data id shape (40, 11)
# new data shape (210023, 11)
# installation_id 0b7cb61e
# installation_id 0b80b297
# current data id shape (244, 11)
# new data shape (210267, 11)
# installation_id 0b87c279
# installation_id 0b887776
# installation_id 0b8ec97d
# installation_id 0b8f08f8
# installation_id 0b90587b
# installation_id 0b9885aa
# current data id shape (120, 11)
# new data shape (210387, 11)
# installation_id 0b9c9bdd
# installation_id 0b9df2fe
# current data id shape (1524, 11)
# new data shape (211911, 11)
# installation_id 0ba38988
# current data id shape (235, 11)
# new data shape (212146, 11)
# installation_id 0bb3b014
# installation_id 0bb3bb7f
# current data id shape (51, 11)
# new data shape (212197, 11)
# installation_id 0bb876f0
# current data id shape (2348, 11)
# new data shape (214545, 11)
# installation_id 0bbbfabc
# installation_id 0bbda624
# installation_id 0bbdf324
# current data id shape (162, 11)
# new data shape (214707, 11)
# installation_id 0bbe501d
# installation_id 0bc3ff21
# installation_id 0bcbfc3f
# installation_id 0bccf0de
# installation_id 0bd158bc
# installation_id 0bdaa2b3
# installation_id 0bdb541b
# installation_id 0bdc1d38
# installation_id 0bdc8dd7
# installation_id 0bdcf67f
# installation_id 0bdecf7b
# installation_id 0be21037
# installation_id 0be3b339
# installation_id 0be4126e
# current data id shape (131, 11)
# new data shape (214838, 11)
# installation_id 0be4d701
# installation_id 0be78e08
# installation_id 0be831c0
# current data id shape (10166, 11)
# new data shape (225004, 11)
# installation_id 0be99182
# installation_id 0bed1d28
# installation_id 0bed589b
# current data id shape (127, 11)
# new data shape (225131, 11)
# installation_id 0bf37d42
# current data id shape (7, 11)
# new data shape (225138, 11)
# installation_id 0bf95a69
# current data id shape (3, 11)
# new data shape (225141, 11)
# installation_id 0bf9bcdc
# installation_id 0bfed8fc
# installation_id 0bff8488
# installation_id 0c019681
# installation_id 0c0f6333
# installation_id 0c11c491
# installation_id 0c11e6a6
# current data id shape (806, 11)
# new data shape (225947, 11)
# installation_id 0c178946
# installation_id 0c17cd78
# installation_id 0c1a446c
# installation_id 0c1cfd5b
# installation_id 0c226845
# installation_id 0c226900
# current data id shape (42, 11)
# new data shape (225989, 11)
# installation_id 0c2f90ba
# installation_id 0c39479e
# installation_id 0c3c0d98
# installation_id 0c3c939f
# installation_id 0c3f9ed1
# installation_id 0c431b0d
# installation_id 0c4f99c6
# installation_id 0c516460
# current data id shape (344, 11)
# new data shape (226333, 11)
# installation_id 0c565b53
# current data id shape (495, 11)
# new data shape (226828, 11)
# installation_id 0c576912
# installation_id 0c599bbc
# installation_id 0c64c7cf
# installation_id 0c73b33c
# installation_id 0c7927b9
# current data id shape (1, 11)
# new data shape (226829, 11)
# installation_id 0c7c21cf
# installation_id 0c7cd3a4
# installation_id 0c7e6b51
# installation_id 0c8918c5
# installation_id 0c947251
# installation_id 0c9474b2
# installation_id 0c9f6419
# installation_id 0ca06b0b
# installation_id 0ca843b3
# installation_id 0ca9ff42
# current data id shape (248, 11)
# new data shape (227077, 11)
# installation_id 0cad4f58
# installation_id 0cb0487b
# installation_id 0cb081d8
# current data id shape (412, 11)
# new data shape (227489, 11)
# installation_id 0cb56246
# current data id shape (443, 11)
# new data shape (227932, 11)
# installation_id 0cb67d40
# installation_id 0cbd6ae5
# installation_id 0cc1d512
# current data id shape (268, 11)
# new data shape (228200, 11)
# installation_id 0cc2a247
# current data id shape (909, 11)
# new data shape (229109, 11)
# installation_id 0cc3fcac
# installation_id 0cc5fd5c
# installation_id 0ccbf56e
# installation_id 0cd05f81
# current data id shape (398, 11)
# new data shape (229507, 11)
# installation_id 0cd0bd1a
# installation_id 0cd310fb
# installation_id 0cd5c4a5
# installation_id 0cd7b2f8
# installation_id 0ce293be
# installation_id 0ce554c5
# installation_id 0ceaa11f
# installation_id 0ceb6116
# current data id shape (9, 11)
# new data shape (229516, 11)
# installation_id 0cec1323
# current data id shape (37, 11)
# new data shape (229553, 11)
# installation_id 0cf2a23c
# current data id shape (869, 11)
# new data shape (230422, 11)
# installation_id 0cf2ab5f
# installation_id 0cf31aa9
# installation_id 0cf3f750
# installation_id 0cf64eb2
# installation_id 0cf88af9
# installation_id 0cf8dc83
# installation_id 0cfb6ad6
# installation_id 0cfb9c5c
# installation_id 0cfebd37
# installation_id 0d095bd2
# installation_id 0d09ed83
# current data id shape (2, 11)
# new data shape (230424, 11)
# installation_id 0d0adefd
# installation_id 0d0f196e
# current data id shape (145, 11)
# new data shape (230569, 11)
# installation_id 0d1948a8
# installation_id 0d1e0970
# installation_id 0d1ef731
# installation_id 0d230220
# current data id shape (458, 11)
# new data shape (231027, 11)
# installation_id 0d2beac0
# installation_id 0d2d289b
# installation_id 0d317094
# installation_id 0d39a952
# installation_id 0d496c43
# installation_id 0d4ac163
# installation_id 0d4b69c4
# installation_id 0d524129
# installation_id 0d553fe3
# installation_id 0d5a0603
# current data id shape (136, 11)
# new data shape (231163, 11)
# installation_id 0d5a1a5e
# current data id shape (4491, 11)
# new data shape (235654, 11)
# installation_id 0d5c0a5c
# installation_id 0d5dcc82
# installation_id 0d65d8e9
# installation_id 0d6709e3
# installation_id 0d6757fa
# installation_id 0d6775ea
# installation_id 0d7a9eb6
# current data id shape (6243, 11)
# new data shape (241897, 11)
# installation_id 0d7e204f
# installation_id 0d7ed521
# installation_id 0d7ee2a5
# installation_id 0d7f1a4b
# installation_id 0d8cdec2
# current data id shape (310, 11)
# new data shape (242207, 11)
# installation_id 0d8dfcb8
# installation_id 0d8ef03d
# installation_id 0d8faef9
# installation_id 0d921886
# installation_id 0d931cbf
# installation_id 0d954adf
# installation_id 0d9bc928
# installation_id 0d9d00d2
# current data id shape (728, 11)
# new data shape (242935, 11)
# installation_id 0d9dd227
# installation_id 0d9e0b05
# installation_id 0da8674f
# installation_id 0da88546
# installation_id 0db1fe01
# installation_id 0db380b1
# current data id shape (557, 11)
# new data shape (243492, 11)
# installation_id 0db46019
# installation_id 0db84fdb
# installation_id 0db9cfbb
# current data id shape (226, 11)
# new data shape (243718, 11)
# installation_id 0dbe5429
# current data id shape (109, 11)
# new data shape (243827, 11)
# installation_id 0dc3e739
# installation_id 0dc846aa
# installation_id 0dcd0738
# installation_id 0dcd5117
# installation_id 0dcda606
# current data id shape (235, 11)
# new data shape (244062, 11)
# installation_id 0dcfd231
# installation_id 0dcfed6c
# installation_id 0dd2c5fd
# installation_id 0dd2edf7
# installation_id 0dd50322
# installation_id 0dd5a344
# installation_id 0dd5afc5
# current data id shape (3270, 11)
# new data shape (247332, 11)
# installation_id 0dd787b4
# installation_id 0dd9d9b4
# installation_id 0ddddc38
# installation_id 0ddf24ea
# installation_id 0df65189
# installation_id 0df79f94
# installation_id 0df955ef
# installation_id 0dfc3ea3
# current data id shape (278, 11)
# new data shape (247610, 11)
# installation_id 0dfef699
# installation_id 0e0292a9
# installation_id 0e02f80d
# current data id shape (2047, 11)
# new data shape (249657, 11)
# installation_id 0e04c038
# installation_id 0e06b371
# current data id shape (554, 11)
# new data shape (250211, 11)
# installation_id 0e0a3652
# current data id shape (136, 11)
# new data shape (250347, 11)
# installation_id 0e0db500
# installation_id 0e137bea
# installation_id 0e1506ef
# current data id shape (2, 11)
# new data shape (250349, 11)
# installation_id 0e195ce7
# installation_id 0e1c2a5b
# installation_id 0e1d56b4
# installation_id 0e29d8a6
# installation_id 0e2d46db
# installation_id 0e2e8dbd
# installation_id 0e2ef298
# installation_id 0e31fa8d
# current data id shape (673, 11)
# new data shape (251022, 11)
# installation_id 0e35db1a
# installation_id 0e38cca7
# installation_id 0e3f37cb
# installation_id 0e3f94d4
# installation_id 0e420504
# installation_id 0e4b416b
# installation_id 0e4cdfee
# installation_id 0e50a7f6
# installation_id 0e521e0d
# installation_id 0e52b017
# installation_id 0e52fdbc
# installation_id 0e5366bd
# installation_id 0e53eb18
# installation_id 0e54d6cc
# installation_id 0e575656
# installation_id 0e66cdab
# current data id shape (120, 11)
# new data shape (251142, 11)
# installation_id 0e6ce372
# current data id shape (1879, 11)
# new data shape (253021, 11)
# installation_id 0e6fab41
# current data id shape (73, 11)
# new data shape (253094, 11)
# installation_id 0e70dddc
# current data id shape (4355, 11)
# new data shape (257449, 11)
# installation_id 0e762624
# installation_id 0e792a70
# current data id shape (7, 11)
# new data shape (257456, 11)
# installation_id 0e7a2539
# installation_id 0e882d76
# installation_id 0e8a7327
# installation_id 0e905dee
# installation_id 0e917138
# installation_id 0e91b373
# installation_id 0e9e117e
# installation_id 0ea6142a
# current data id shape (570, 11)
# new data shape (258026, 11)
# installation_id 0eb31597
# installation_id 0eb7ee76
# installation_id 0eb9a3f3
# installation_id 0ebec31e
# installation_id 0ec217a6
# installation_id 0ec3497e
# installation_id 0ec92788
# current data id shape (122, 11)
# new data shape (258148, 11)
# installation_id 0ecb2841
# installation_id 0ed19b01
# installation_id 0ed3df78
# installation_id 0ed88e7d
# current data id shape (23, 11)
# new data shape (258171, 11)
# installation_id 0ed930d2
# installation_id 0eee798b
# installation_id 0eef4487
# installation_id 0ef2edff
# installation_id 0ef56279
# current data id shape (134, 11)
# new data shape (258305, 11)
# installation_id 0ef5a7b0
# installation_id 0ef62aad
# current data id shape (336, 11)
# new data shape (258641, 11)
# installation_id 0f00cec0
# installation_id 0f04134b
# installation_id 0f07e13a
# current data id shape (220, 11)
# new data shape (258861, 11)
# installation_id 0f0b5b02
# installation_id 0f0dbdb5
# installation_id 0f0eb744
# current data id shape (1386, 11)
# new data shape (260247, 11)
# installation_id 0f11e020
# current data id shape (494, 11)
# new data shape (260741, 11)
# installation_id 0f189120
# installation_id 0f1c82f0
# installation_id 0f291d0c
# installation_id 0f2a18ee
# installation_id 0f2a8550
# current data id shape (839, 11)
# new data shape (261580, 11)
# installation_id 0f2e23b4
# current data id shape (1, 11)
# new data shape (261581, 11)
# installation_id 0f331094
# current data id shape (924, 11)
# new data shape (262505, 11)
# installation_id 0f35f808
# current data id shape (110, 11)
# new data shape (262615, 11)
# installation_id 0f373f3d
# installation_id 0f3a962d
# installation_id 0f3c877f
# installation_id 0f3ec88e
# installation_id 0f410248
# installation_id 0f41e2f7
# installation_id 0f4777de
# installation_id 0f47f086
# current data id shape (1557, 11)
# new data shape (264172, 11)
# installation_id 0f48dbfc
# installation_id 0f4dda0a
# current data id shape (138, 11)
# new data shape (264310, 11)
# installation_id 0f568eb8
# current data id shape (255, 11)
# new data shape (264565, 11)
# installation_id 0f5b30fb
# current data id shape (1005, 11)
# new data shape (265570, 11)
# installation_id 0f5c2d76
# installation_id 0f60281d
# installation_id 0f69c792
# installation_id 0f6a13b3
# installation_id 0f6b7373
# installation_id 0f6c7e81
# installation_id 0f71b1f1
# installation_id 0f72b7da
# installation_id 0f77265d
# installation_id 0f77f560
# installation_id 0f7c782d
# installation_id 0f7d6f52
# installation_id 0f857d5b
# installation_id 0f8a0eb2
# installation_id 0f90249e
# installation_id 0f96c2a8
# installation_id 0fa2ac20
# current data id shape (1055, 11)
# new data shape (266625, 11)
# installation_id 0fa3edde
# current data id shape (558, 11)
# new data shape (267183, 11)
# installation_id 0fa596e9
# installation_id 0fa644f7
# current data id shape (110, 11)
# new data shape (267293, 11)
# installation_id 0fa667da
# installation_id 0facb764
# installation_id 0facbafd
# installation_id 0fb61936
# installation_id 0fba4d09
# installation_id 0fba73e5
# installation_id 0fbc47c6
# current data id shape (342, 11)
# new data shape (267635, 11)
# installation_id 0fbd0bb4
# installation_id 0fbed6c6
# installation_id 0fc83e2b
# installation_id 0fc85acd
# installation_id 0fc960cd
# installation_id 0fc98586
# installation_id 0fcc3c2c
# installation_id 0fd844d6
# installation_id 0fdd4813
# installation_id 0fdd65f6
# current data id shape (624, 11)
# new data shape (268259, 11)
# installation_id 0fdd8dd3
# installation_id 0fe146bf
# installation_id 0fe32f2a
# installation_id 0fedda6e
# installation_id 0fedf097
# installation_id 0ff0071a
# installation_id 0ff1e0d9
# installation_id 0ff84dd3
# installation_id 1001b649
# current data id shape (4, 11)
# new data shape (268263, 11)
# installation_id 1006240e
# installation_id 100844d4
# installation_id 100b0f77
# installation_id 100efc3c
# installation_id 100f4a76
# installation_id 1014b8ac
# current data id shape (1500, 11)
# new data shape (269763, 11)
# installation_id 10189f14
# current data id shape (1226, 11)
# new data shape (270989, 11)
# installation_id 101dfe1b
# installation_id 101faf2f
# current data id shape (142, 11)
# new data shape (271131, 11)
# installation_id 10224630
# current data id shape (2414, 11)
# new data shape (273545, 11)
# installation_id 10269078
# installation_id 102cacee
# installation_id 10337552
# current data id shape (947, 11)
# new data shape (274492, 11)
# installation_id 1033caba
# installation_id 103d5213
# installation_id 1043cb36
# installation_id 1044bf0c
# installation_id 10476374
# installation_id 105463b2
# installation_id 1059b303
# installation_id 105dec0c
# installation_id 10629430
# current data id shape (119, 11)
# new data shape (274611, 11)
# installation_id 10682009
# installation_id 10734096
# current data id shape (1141, 11)
# new data shape (275752, 11)
# installation_id 107c95d8
# current data id shape (3667, 11)
# new data shape (279419, 11)
# installation_id 107d7354
# installation_id 107e6f09
# current data id shape (995, 11)
# new data shape (280414, 11)
# installation_id 107e82d1
# installation_id 108191b9
# installation_id 1085f823
# installation_id 108634a9
# current data id shape (95, 11)
# new data shape (280509, 11)
# installation_id 108a583e
# installation_id 108a7ef6
# installation_id 108ee0b1
# installation_id 1091d87b
# current data id shape (285, 11)
# new data shape (280794, 11)
# installation_id 109301f4
# installation_id 10944346
# installation_id 1096ef28
# installation_id 1098ba58
# current data id shape (552, 11)
# new data shape (281346, 11)
# installation_id 109936be
# installation_id 109a4bce
# current data id shape (1016, 11)
# new data shape (282362, 11)
# installation_id 10a3bbc2
# installation_id 10a863a8
# installation_id 10ab8524
# installation_id 10ac4a88
# current data id shape (192, 11)
# new data shape (282554, 11)
# installation_id 10b3127f
# installation_id 10b6a958
# installation_id 10b85970
# current data id shape (289, 11)
# new data shape (282843, 11)
# installation_id 10b95d3e
# current data id shape (389, 11)
# new data shape (283232, 11)
# installation_id 10bab067
# current data id shape (1, 11)
# new data shape (283233, 11)
# installation_id 10bdc99a
# installation_id 10c3c2c7
# installation_id 10c997f9
# installation_id 10c9c489
# installation_id 10cc1be5
# installation_id 10cc88ef
# installation_id 10cf4da9
# installation_id 10d09109
# installation_id 10d7e309
# installation_id 10da6d5f
# installation_id 10e25829
# installation_id 10e4df32
# installation_id 10e9e941
# current data id shape (331, 11)
# new data shape (283564, 11)
# installation_id 10f22a60
# current data id shape (401, 11)
# new data shape (283965, 11)
# installation_id 10f7bed2
# current data id shape (123, 11)
# new data shape (284088, 11)
# installation_id 10f85ea6
# installation_id 110209f6
# installation_id 110353a9
# installation_id 1104665a
# installation_id 11052b00
# current data id shape (1575, 11)
# new data shape (285663, 11)
# installation_id 1108a6a3
# installation_id 110ba11d
# installation_id 110da640
# current data id shape (534, 11)
# new data shape (286197, 11)
# installation_id 11193ff0
# installation_id 111cfb8d
# installation_id 1121ed33
# installation_id 11235b2b
# installation_id 1123e9b8
# current data id shape (898, 11)
# new data shape (287095, 11)
# installation_id 11353e10
# current data id shape (177, 11)
# new data shape (287272, 11)
# installation_id 11363c14
# installation_id 11399986
# installation_id 113e6e4d
# current data id shape (504, 11)
# new data shape (287776, 11)
# installation_id 1141b957
# installation_id 1146c21d
# installation_id 114a661c
# current data id shape (4, 11)
# new data shape (287780, 11)
# installation_id 114adc72
# installation_id 114ce781
# installation_id 1150a111
# installation_id 1150ce68
# current data id shape (911, 11)
# new data shape (288691, 11)
# installation_id 1158a75c
# current data id shape (293, 11)
# new data shape (288984, 11)
# installation_id 11598802
# installation_id 115c97cc
# current data id shape (2228, 11)
# new data shape (291212, 11)
# installation_id 11633b75
# installation_id 116c3ccc
# installation_id 1177c6fd
# installation_id 1179e7de
# installation_id 117a6053
# current data id shape (532, 11)
# new data shape (291744, 11)
# installation_id 117b15de
# installation_id 11803287
# installation_id 1186f0c9
# installation_id 11890186
# installation_id 1189cdb9
# installation_id 118afe5c
# current data id shape (2744, 11)
# new data shape (294488, 11)
# installation_id 118b75d3
# installation_id 11920dee
# installation_id 1192a921
# current data id shape (914, 11)
# new data shape (295402, 11)
# installation_id 1196d776
# current data id shape (205, 11)
# new data shape (295607, 11)
# installation_id 119707f5
# installation_id 119d3780
# installation_id 11a02c0d
# installation_id 11a3dee9
# installation_id 11af71e9
# installation_id 11b0e977
# installation_id 11b2e8c5
# installation_id 11b5396d
# installation_id 11ba64c4
# ...
# installation_id 97e81916
# current data id shape (1569, 11)
# new data shape (2635815, 11)
# installation_id 97f48813
# installation_id 97f88e89
# installation_id 97fd4a14
# installation_id 97ff5ba5
# installation_id 98023c66
# current data id shape (562, 11)
# new data shape (2636377, 11)
# installation_id 98044312
# installation_id 9806572c
# installation_id 98102e27
# current data id shape (369, 11)
# new data shape (2636746, 11)
# installation_id 98140bdd
# installation_id 9814d8d1
# installation_id 9815141d
# installation_id 981c6701
# installation_id 98207784
# current data id shape (4, 11)
# new data shape (2636750, 11)
# installation_id 98268c77
# installation_id 982948e3
# installation_id 98337af1
# installation_id 983d7cb1
# installation_id 983dd850
# installation_id 983efe20
# installation_id 983f5249
# installation_id 98416c8e
# current data id shape (132, 11)
# new data shape (2636882, 11)
# installation_id 984683d0
# current data id shape (99, 11)
# new data shape (2636981, 11)
# installation_id 984ca333
# installation_id 984f43d1
# installation_id 9851f635
# current data id shape (250, 11)
# new data shape (2637231, 11)
# installation_id 98568d05
# installation_id 985c4585
# installation_id 9860322d
# installation_id 9860ac16
# installation_id 9860ebae
# installation_id 9864e053
# installation_id 986b8a25
# installation_id 986b8f26
# installation_id 98711876
# installation_id 98804f80
# installation_id 98841415
# installation_id 9884f9f3
# current data id shape (1899, 11)
# new data shape (2639130, 11)
# installation_id 98915aef
# installation_id 98a23fca
# installation_id 98a60d7c
# installation_id 98a70c31
# installation_id 98ab32af
# installation_id 98abe3d2
# installation_id 98af7368
# installation_id 98bc5e18
# installation_id 98bc700b
# installation_id 98bd76e9
# installation_id 98bd917a
# installation_id 98c28220
# current data id shape (240, 11)
# new data shape (2639370, 11)
# installation_id 98c8e99a
# current data id shape (330, 11)
# new data shape (2639700, 11)
# installation_id 98ca02a7
# installation_id 98cecbf4
# installation_id 98d1db81
# installation_id 98d2c5c7
# installation_id 98dad818
# installation_id 98ddfbb8
# installation_id 98e0e15f
# installation_id 98e16f3d
# installation_id 98e4a512
# current data id shape (623, 11)
# new data shape (2640323, 11)
# installation_id 98e5e773
# current data id shape (3920, 11)
# new data shape (2644243, 11)
# installation_id 98ef9f03
# installation_id 98f2ab8d
# current data id shape (2988, 11)
# new data shape (2647231, 11)
# installation_id 98f51388
# current data id shape (775, 11)
# new data shape (2648006, 11)
# installation_id 98f80e88
# installation_id 98f9090d
# installation_id 98ff2325
# installation_id 9908a2de
# installation_id 9910ddf8
# installation_id 9915fb38
# installation_id 9918fb8d
# current data id shape (210, 11)
# new data shape (2648216, 11)
# installation_id 991e453e
# current data id shape (320, 11)
# new data shape (2648536, 11)
# installation_id 9920a2e2
# installation_id 9927eb92
# installation_id 9928918a
# installation_id 992cd228
# current data id shape (136, 11)
# new data shape (2648672, 11)
# installation_id 99301841
# installation_id 99312c17
# installation_id 9933bbf5
# current data id shape (569, 11)
# new data shape (2649241, 11)
# installation_id 99386a33
# installation_id 993b2ed4
# installation_id 99405c62
# installation_id 9941ceae
# installation_id 994491d0
# installation_id 9945adb5
# installation_id 9948ab89
# installation_id 9948f0c0
# installation_id 99521d4b
# installation_id 99556f13
# installation_id 995789a3
# installation_id 99582172
# installation_id 995b8d19
# installation_id 9963728a
# installation_id 9967ec2c
# installation_id 996c185b
# current data id shape (389, 11)
# new data shape (2649630, 11)
# installation_id 9970d796
# installation_id 99720253
# installation_id 99758fb1
# installation_id 9978f49b
# installation_id 9996e76b
# installation_id 99977bb4
# installation_id 999951fc
# current data id shape (1692, 11)
# new data shape (2651322, 11)
# installation_id 999d9275
# installation_id 99a186c2
# installation_id 99a1ca54
# current data id shape (859, 11)
# new data shape (2652181, 11)
# installation_id 99a8e2b3
# installation_id 99a9057b
# installation_id 99ab3b2f
# installation_id 99ad02ea
# installation_id 99af1ce6
# current data id shape (34, 11)
# new data shape (2652215, 11)
# installation_id 99afbcab
# installation_id 99affcfb
# installation_id 99b13494
# current data id shape (174, 11)
# new data shape (2652389, 11)
# installation_id 99b4cbbe
# installation_id 99b52784
# installation_id 99b5cc97
# installation_id 99b98ccb
# installation_id 99bbc160
# installation_id 99be10dc
# installation_id 99c124ae
# current data id shape (904, 11)
# new data shape (2653293, 11)
# installation_id 99c37647
# current data id shape (1285, 11)
# new data shape (2654578, 11)
# installation_id 99cc324a
# installation_id 99d35f2c
# installation_id 99d4da7d
# installation_id 99d8fa10
# installation_id 99db7c5b
# installation_id 99dcb252
# installation_id 99de7967
# current data id shape (97, 11)
# new data shape (2654675, 11)
# installation_id 99e0c131
# current data id shape (397, 11)
# new data shape (2655072, 11)
# installation_id 99e423f3
# current data id shape (2812, 11)
# new data shape (2657884, 11)
# installation_id 99efa102
# installation_id 99f0a1bb
# current data id shape (206, 11)
# new data shape (2658090, 11)
# installation_id 99f33a1a
# current data id shape (86, 11)
# new data shape (2658176, 11)
# installation_id 99f93572
# installation_id 99fbe92a
# installation_id 99fe5c0f
# installation_id 9a037ab5
# current data id shape (258, 11)
# new data shape (2658434, 11)
# installation_id 9a0f1035
# installation_id 9a10c83d
# current data id shape (46, 11)
# new data shape (2658480, 11)
# installation_id 9a175c97
# installation_id 9a19c08b
# current data id shape (1231, 11)
# new data shape (2659711, 11)
# installation_id 9a1b8084
# installation_id 9a1cc8ba
# installation_id 9a2086d2
# installation_id 9a2b5020
# installation_id 9a30e52f
# installation_id 9a30e83b
# current data id shape (21, 11)
# new data shape (2659732, 11)
# installation_id 9a31b166
# installation_id 9a31bb71
# installation_id 9a31bcac
# current data id shape (6253, 11)
# new data shape (2665985, 11)
# installation_id 9a3690b5
# installation_id 9a37e19f
# installation_id 9a386bd7
# installation_id 9a47a396
# installation_id 9a4c0ea6
# installation_id 9a50f8b8
# current data id shape (427, 11)
# new data shape (2666412, 11)
# installation_id 9a52f00c
# installation_id 9a53b808
# installation_id 9a5f1f3a
# current data id shape (274, 11)
# new data shape (2666686, 11)
# installation_id 9a5feb89
# installation_id 9a6236e5
# current data id shape (137, 11)
# new data shape (2666823, 11)
# installation_id 9a6a22e3
# installation_id 9a6d0ba3
# installation_id 9a6db1b6
# current data id shape (141, 11)
# new data shape (2666964, 11)
# installation_id 9a6f7b58
# installation_id 9a6ffb62
# current data id shape (3104, 11)
# new data shape (2670068, 11)
# installation_id 9a702a86
# current data id shape (3, 11)
# new data shape (2670071, 11)
# installation_id 9a746015
# current data id shape (151, 11)
# new data shape (2670222, 11)
# installation_id 9a7c3453
# installation_id 9a898bba
# current data id shape (5175, 11)
# new data shape (2675397, 11)
# installation_id 9a8d2321
# installation_id 9a8d324b
# installation_id 9a8faa22
# installation_id 9a8fca4c
# installation_id 9a93a2df
# installation_id 9a9552c6
# installation_id 9a970c94
# current data id shape (725, 11)
# new data shape (2676122, 11)
# installation_id 9a988b52
# installation_id 9a9ea4ac
# installation_id 9aab9fa1
# installation_id 9aae2256
# installation_id 9ab41cf0
# installation_id 9ab5e889
# installation_id 9abb6144
# current data id shape (3151, 11)
# new data shape (2679273, 11)
# installation_id 9ac4c321
# installation_id 9ad0f103
# installation_id 9ad49453
# installation_id 9ad655c3
# installation_id 9ad7dd5b
# current data id shape (247, 11)
# new data shape (2679520, 11)
# installation_id 9ad9de0c
# installation_id 9adc3132
# installation_id 9ae36027
# installation_id 9ae5eea6
# current data id shape (9, 11)
# new data shape (2679529, 11)
# installation_id 9aef8adc
# installation_id 9af1cdeb
# installation_id 9af403fb
# installation_id 9af4d76b
# current data id shape (139, 11)
# new data shape (2679668, 11)
# installation_id 9afd864d
# installation_id 9aff7d33
# current data id shape (604, 11)
# new data shape (2680272, 11)
# installation_id 9b070738
# installation_id 9b075a0b
# current data id shape (443, 11)
# new data shape (2680715, 11)
# installation_id 9b0babce
# installation_id 9b0c8a23
# installation_id 9b135ddc
# installation_id 9b204244
# current data id shape (200, 11)
# new data shape (2680915, 11)
# installation_id 9b2542d8
# installation_id 9b2f8ab9
# installation_id 9b3052d5
# installation_id 9b3b5a95
# installation_id 9b4374e6
# installation_id 9b43bc6b
# current data id shape (56, 11)
# new data shape (2680971, 11)
# installation_id 9b490a3c
# current data id shape (767, 11)
# new data shape (2681738, 11)
# installation_id 9b55ca4a
# current data id shape (41, 11)
# new data shape (2681779, 11)
# installation_id 9b5630be
# current data id shape (1216, 11)
# new data shape (2682995, 11)
# installation_id 9b57e276
# installation_id 9b5e55b8
# installation_id 9b62e525
# installation_id 9b631660
# installation_id 9b69c8b8
# installation_id 9b6a09db
# installation_id 9b6c5e60
# current data id shape (7462, 11)
# new data shape (2690457, 11)
# installation_id 9b6f2154
# installation_id 9b732c95
# installation_id 9b73ad25
# current data id shape (450, 11)
# new data shape (2690907, 11)
# installation_id 9b7d6baa
# current data id shape (1, 11)
# new data shape (2690908, 11)
# installation_id 9b8113eb
# installation_id 9b82148c
# installation_id 9b82e04e
# installation_id 9b83ea6a
# installation_id 9b847f65
# installation_id 9b863643
# installation_id 9b8810fc
# installation_id 9b8afe8a
# installation_id 9b8cd27b
# installation_id 9b9090eb
# current data id shape (644, 11)
# new data shape (2691552, 11)
# installation_id 9b909d49
# installation_id 9b94aaa1
# installation_id 9b9b9f88
# installation_id 9b9dad66
# current data id shape (587, 11)
# new data shape (2692139, 11)
# installation_id 9ba1bd35
# installation_id 9ba2ecaa
# installation_id 9ba3aac2
# installation_id 9baa361d
# installation_id 9babb182
# installation_id 9badcbeb
# installation_id 9bb525c2
# installation_id 9bb7b78d
# installation_id 9bb7ef44
# current data id shape (911, 11)
# new data shape (2693050, 11)
# installation_id 9bc0aa21
# current data id shape (7235, 11)
# new data shape (2700285, 11)
# installation_id 9bc1bbb2
# current data id shape (386, 11)
# new data shape (2700671, 11)
# installation_id 9bc61bc7
# installation_id 9bcb42c1
# current data id shape (942, 11)
# new data shape (2701613, 11)
# installation_id 9bcbff3c
# current data id shape (478, 11)
# new data shape (2702091, 11)
# installation_id 9bcced2e
# installation_id 9bd21cf3
# installation_id 9bd24dbd
# installation_id 9bd8ccf0
# installation_id 9bd91555
# installation_id 9bdec0cf
# installation_id 9befb534
# installation_id 9befd418
# installation_id 9bf11b57
# installation_id 9bf17fa9
# installation_id 9bf2c48f
# current data id shape (4, 11)
# new data shape (2702095, 11)
# installation_id 9bfa926b
# installation_id 9c00f81b
# installation_id 9c01b3b5
# installation_id 9c02c579
# current data id shape (1560, 11)
# new data shape (2703655, 11)
# installation_id 9c06495d
# installation_id 9c08902e
# installation_id 9c0cb7c6
# current data id shape (1940, 11)
# new data shape (2705595, 11)
# installation_id 9c1103b2
# installation_id 9c163782
# installation_id 9c1702f6
# installation_id 9c1b5bd3
# installation_id 9c231536
# installation_id 9c23e633
# installation_id 9c2b44ae
# installation_id 9c2db749
# current data id shape (258, 11)
# new data shape (2705853, 11)
# installation_id 9c2f35fe
# current data id shape (274, 11)
# new data shape (2706127, 11)
# installation_id 9c308c33
# installation_id 9c362a17
# installation_id 9c38b99d
# installation_id 9c415c54
# installation_id 9c41bf27
# installation_id 9c43b21f
# installation_id 9c44ef4e
# installation_id 9c4ce447
# installation_id 9c4f266e
# current data id shape (1889, 11)
# new data shape (2708016, 11)
# installation_id 9c50720e
# current data id shape (635, 11)
# new data shape (2708651, 11)
# installation_id 9c543e38
# installation_id 9c576851
# installation_id 9c605055
# installation_id 9c719985
# installation_id 9c7bc7f3
# installation_id 9c85e7e8
# installation_id 9c8ab011
# installation_id 9c942be8
# installation_id 9c985eda
# installation_id 9c991b58
# installation_id 9c9b565c
# current data id shape (7, 11)
# new data shape (2708658, 11)
# installation_id 9c9b9488
# installation_id 9c9e6d5c
# installation_id 9ca10f0c
# installation_id 9ca8a4d1
# current data id shape (831, 11)
# new data shape (2709489, 11)
# installation_id 9cacc983
# installation_id 9cad353f
# installation_id 9cae5942
# installation_id 9cb218cb
# installation_id 9cb23e4c
# installation_id 9cb84bec
# current data id shape (648, 11)
# new data shape (2710137, 11)
# installation_id 9cbf434e
# installation_id 9cbfcbbc
# installation_id 9cc6b4c5
# installation_id 9cc6dbb2
# installation_id 9cc78119
# installation_id 9cc81584
# current data id shape (192, 11)
# new data shape (2710329, 11)
# installation_id 9ccde0f7
# current data id shape (805, 11)
# new data shape (2711134, 11)
# installation_id 9cce8259
# current data id shape (429, 11)
# new data shape (2711563, 11)
# installation_id 9ccf6afe
# installation_id 9cd78e58
# installation_id 9cd9ee1e
# current data id shape (1, 11)
# new data shape (2711564, 11)
# installation_id 9cdc424f
# installation_id 9cde2baa
# installation_id 9cdf78d4
# installation_id 9ce2d074
# current data id shape (194, 11)
# new data shape (2711758, 11)
# installation_id 9ce3949c
# installation_id 9ce566e3
# installation_id 9ce71398
# installation_id 9cef2059
# current data id shape (497, 11)
# new data shape (2712255, 11)
# installation_id 9cefacd0
# current data id shape (1193, 11)
# new data shape (2713448, 11)
# installation_id 9cf4c7a4
# installation_id 9cf80068
# installation_id 9cf97f3f
# installation_id 9cfb790f
# installation_id 9cfdf41e
# installation_id 9cfe747c
# installation_id 9d083b79
# current data id shape (1124, 11)
# new data shape (2714572, 11)
# installation_id 9d16f57b
# installation_id 9d173e62
# installation_id 9d1c7962
# installation_id 9d229b2a
# installation_id 9d23b665
# installation_id 9d25b795
# installation_id 9d2ad72f
# installation_id 9d2b1a55
# installation_id 9d37b73d
# current data id shape (76, 11)
# new data shape (2714648, 11)
# installation_id 9d3af67d
# installation_id 9d3cf746
# current data id shape (320, 11)
# new data shape (2714968, 11)
# installation_id 9d3eb33a
# current data id shape (8759, 11)
# new data shape (2723727, 11)
# installation_id 9d4048ca
# installation_id 9d43df2c
# current data id shape (296, 11)
# new data shape (2724023, 11)
# installation_id 9d446a0f
# installation_id 9d48836a
# installation_id 9d4f4366
# installation_id 9d4f7fc9
# installation_id 9d544e2a
# installation_id 9d54a178
# current data id shape (168, 11)
# new data shape (2724191, 11)
# installation_id 9d553021
# installation_id 9d570bf2
# current data id shape (1, 11)
# new data shape (2724192, 11)
# installation_id 9d58b502
# installation_id 9d595f2f
# current data id shape (920, 11)
# new data shape (2725112, 11)
# installation_id 9d5cea44
# installation_id 9d6131ba
# installation_id 9d633649
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-373-de4391cf9b08> in <module>
#       3 start_time = time.time()
#       4
# ----> 5 new_data = truncate_data(train)
#       6
#       7 print("Temps d execution : %s secondes ---" % (time.time() - start_time))
#
# <ipython-input-371-a3441f559aa0> in truncate_data(data, how)
#      16     for id in unique_id:
#      17         print('installation_id', id)
# ---> 18         test_id = data[data['installation_id'] == id]
#      19         n = test_id[(test_id['type']=='Assessment') & (test_id['event_code'] == 2000)].count()[0] #nombre d'assessment commencés
#      20         if n!=0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2916         # Do we have a (boolean) 1d indexer?
#    2917         if com.is_bool_indexer(key):
# -> 2918             return self._getitem_bool_array(key)
#    2919
#    2920         # We are left with two options: a single key, and a collection of keys,
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2966         # be reindexed to match DataFrame rows
#    2967         key = check_bool_indexer(self.index, key)
# -> 2968         indexer = key.nonzero()[0]
#    2969         return self._take(indexer, axis=0)
#    2970
#
# KeyboardInterrupt:

# %%
def trucate(data, prop):
    """
    input: train
            the ratio of the assessments to keep
    output: train trucated from the starrt of the assesment n
    """
    df = pd.DataFrame()
    
    games = ['Bird Measurer', 'Cart Balancer', 'Cauldron Filler', 'Chest Sorter', 'Mushroom Sorter']
    
    # Loop on the 5 games
    for game in games:
        tmp = data[data['title'].str.contains(game)]
        
        # Filter the last event : 4110/4100 (code)
        if game == 'Bird Measurer':
            tmp = tmp[(tmp['event_code'] == 4110) | (tmp['event_code'] == 4100)]
        else:
            tmp = tmp[tmp['event_code'] == 4100]
    
        # num_correct and num_incorrect
        correct = ["NA" for i in range(np.shape(tmp)[0])]
        incorrect = ["NA" for i in range(np.shape(tmp)[0])]
        for i in range(np.shape(tmp)[0]):
            if ('correct":false' in tmp.loc[tmp.index[i], 'event_data']):
                correct[i] = 0
                incorrect[i] = 1
            elif ('correct":true' in tmp.loc[tmp.index[i], 'event_data']):
                correct[i] = 1
                incorrect[i] = 0
            else:
                correct[i] = 'NA'
                incorrect[i] = 'NA'
        tmp['num_correct'] = correct
        tmp['num_incorrect'] = incorrect
        tmp = pd.DataFrame(tmp.groupby(('installation_id')).sum())
        
        df = pd.concat([df, tmp])
        
    df = df.reset_index()[['installation_id','num_correct','num_incorrect']]
    
    df['num_attempt'] = df['num_correct'] + df['num_incorrect']
    
    df['threshold'] = (df['num_attempt']*prop).astype(int)
    return(df)
