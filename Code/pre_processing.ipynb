# %% [markdown]
# # Settings

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# # Loading the data

# %%
sample_submission = pd.read_csv("C:/Users/odeli/Desktop/dataCamp_data/sample_submission.csv")
test = pd.read_csv("C:/Users/odeli/Desktop/dataCamp_data/test.csv")
specs = pd.read_csv("C:/Users/odeli/Desktop/dataCamp_data/specs.csv")
train_labels = pd.read_csv("C:/Users/odeli/Desktop/dataCamp_data/train_labels.csv")
train = pd.read_csv("C:/Users/odeli/Desktop/dataCamp_data/train.csv")

# %%
print('Shapes:\n - train: ', np.shape(train), '\n - train_labels: ',np.shape(train_labels), '\n - test: ',np.shape(test), '\n - specs: ',np.shape(specs), '\n - sample_submission: ',np.shape(sample_submission))
# Out:
# Shapes:
#  - train:  (11341042, 11)
#  - train_labels:  (17690, 7)
#  - test:  (1156414, 11)
#  - specs:  (386, 3)
#  - sample_submission:  (1000, 2)

# %% [markdown]
# ## Making labels

# %% [markdown]
# The first very important thing to do is to create the labels.
# As we said the right information is contained in the event_data column.
# This column is a dictionary with a variable size for each line.

# %% [markdown]
# Organisation of the information recorded by the application:
#     * When a child downloads the app an id is created: id_installation
#     * When he starts playing a game an other id is created: game_session
#     * Inside a game_session many things can be done by the gamer. Every event has its own id: event_id. The different possible events are caracterized by a code contained in the event_code column.
# The only useful events to build the labels are the last ones in a game session: they correspond to the succes or the failure of the game in a given game_session. The corrresponding event_code is 4100 for 4 of the 5 games and 4110 for the last one (Bird Measurer).

# %%
def get_accuracy(data):
    """
    input: data
    output: data_labels for each of the 5 games
    """
    
    df = pd.DataFrame()
    
    games = ['Bird Measurer', 'Cart Balancer', 'Cauldron Filler', 'Chest Sorter', 'Mushroom Sorter']
    
    # Loop on the 5 games
    for game in games:
        tmp = data[data['title'].str.contains(game)]
        
        # Filter the last event : 4110/4100 (code)
        if game == 'Bird Measurer':
            tmp = tmp[(tmp['event_code'] == 4110) | (tmp['event_code'] == 4100)]
        else:
            tmp = tmp[tmp['event_code'] == 4100]
    
        # num_correct and num_incorrect
        correct = ["NA" for i in range(np.shape(tmp)[0])]
        incorrect = ["NA" for i in range(np.shape(tmp)[0])]
        for i in range(np.shape(tmp)[0]):
            if ('correct":false' in tmp.loc[tmp.index[i], 'event_data']):
                correct[i] = 0
                incorrect[i] = 1
            elif ('correct":true' in tmp.loc[tmp.index[i], 'event_data']):
                correct[i] = 1
                incorrect[i] = 0
            else:
                correct[i] = 'NA'
                incorrect[i] = 'NA'
        tmp['num_correct'] = correct
        tmp['num_incorrect'] = incorrect
        tmp = pd.DataFrame(tmp.groupby(('installation_id','game_session','title')).sum())
            
        # accuracy
        accuracy = tmp['num_correct'] / (tmp['num_correct'] + tmp['num_incorrect'])
        tmp['accuracy'] = accuracy

        # accuracy_group
        tmp["accuracy_group"] = tmp["accuracy"].apply(lambda x: 0 if x==0 else (1 if x<0.5 else (2 if x<0.9 else 3)))
        df = pd.concat([df, tmp])
        
    df = df.reset_index()[['game_session','installation_id','title','num_correct','num_incorrect','accuracy','accuracy_group']]
    return(df)

# %%
my_train_labels = get_accuracy(train)
# Out:
# C:\Users\odeli\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.

# %%
my_train_labels = my_train_labels.sort_values(['installation_id', 'game_session']).reset_index(drop=True)
#my_train_labels.head()

# %%
np.shape(my_train_labels), np.shape(train_labels)
# Out:
# ((17692, 7), (17690, 7))

# %% [markdown]
# ## The test file

# %% [markdown]
# How many distinct installation_id in the different files:

# %%
len(set(test['installation_id'])), len(set(train['installation_id'])) ,len(set(train_labels['installation_id'])), len(set(my_train_labels['installation_id']))
# Out:
# (1000, 17000, 3614, 3614)

# %% [markdown]
# Shape of the sample submission file:

# %%
np.shape(sample_submission)
# Out:
# (1000, 2)

# %% [markdown]
# Il y a 1000 enfants distincts dont on doit prédire l'accuracy dans le test : c'est exactement le nombre de ligne du file sample_submission donc cohérent.
# Reste à comprendre ce que sont les autres lignes du test

# %% [markdown]
# Y a-t-il des installation_id communs dans le train et dans le test ? (NON)

# %%
i = 0
for id in set(test['installation_id']):
    if(id in set(train['installation_id'])):
        i = i+1
print(i)

# %% [markdown]
# Il y a 1000 enfants distincts ayant fait un assesement dans le test: c'est eux que l'on doit prédire.
# De plus aucun de ces enfants ne sont presents dans le train.

# %% [markdown]
# Que se passe-t-il quand on applique la fonction get_accuracy sur le test

# %%
test_labels = get_accuracy(test)
# Out:
# C:\Users\odeli\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.

# %%
np.shape(test_labels)
# Out:
# (2018, 7)

# %%
len(set(test_labels['installation_id']))
# Out:
# 557

# %% [markdown]
# Les résultats obtenus sont étranges: necessite approfondissement

# %% [markdown]
# Test data
#
# Per installation_id, the last row contains the event start of the assessment (event_code 2000).
#
# We need to predict the accuracy_group for this assessment.
#
# Note: In the test data, you may find previous assessments (with their outcomes, event_code 4100 or 4110)

# %% [markdown]
# Pour 'c31c4183' cb d'assesment poursuivi jusqu'à la fin (debut: 2000  et fin 4100/4110)

# %%
np.shape(test[(test['installation_id'] == 'c31c4183') & (test['type'] == 'Assessment') & ((test['event_code'] == 4100) | (test['event_code'] == 4110))])
# Out:
# (11, 11)

# %%
test_labels[test_labels['installation_id'] == 'c31c4183']
# Out:
#           game_session installation_id                       title  \
# 231   151807bba56c5059        c31c4183  Bird Measurer (Assessment)
# 694   6a817f6a1fee05d7        c31c4183  Cart Balancer (Assessment)
# 1514  7a70d528a32097ab        c31c4183   Chest Sorter (Assessment)
#
#       num_correct  num_incorrect  accuracy  accuracy_group
# 231             1              3      0.25               1
# 694             1              3      0.25               1
# 1514            0              3      0.00               0

# %% [markdown]
# Nombre d'assesment commencé par chaque installation_id dans le train

# %%
train[train['event_code'] == 2000].groupby('installation_id').count()
# Out:
#                  event_id  game_session  timestamp  event_data  event_count  \
# installation_id
# 0001e90f               10            10         10          10           10
# 000447c4                5             5          5           5            5
# 0006a69f               80            80         80          80           80
# 0006c192               50            50         50          50           50
# 0009a5a9                7             7          7           7            7
# 0011edc8               14            14         14          14           14
# 00129856                9             9          9           9            9
# 0016b7cc               23            23         23          23           23
# 00195df7                7             7          7           7            7
# 001d0ed0               52            52         52          52           52
# 002114ae                5             5          5           5            5
# 00219589                3             3          3           3            3
# 00225f67               25            25         25          25           25
# 00279ac5               99            99         99          99           99
# 002c8bae                1             1          1           1            1
# 002db7e3               75            75         75          75           75
# 003372b0               57            57         57          57           57
# 0034471d                1             1          1           1            1
# 0038b87c               12            12         12          12           12
# 003a6dff                1             1          1           1            1
# 004adee1                2             2          2           2            2
# 004c2091               49            49         49          49           49
# 0050f7a8                7             7          7           7            7
# 0051064f               12            12         12          12           12
# 00511b72                2             2          2           2            2
# 0052394a                7             7          7           7            7
# 00524526                1             1          1           1            1
# 005ccc35                7             7          7           7            7
# 00634433               11            11         11          11           11
# 00651949                1             1          1           1            1
# ...                   ...           ...        ...         ...          ...
# ffacf14c                3             3          3           3            3
# ffb2c879                1             1          1           1            1
# ffb6a706                3             3          3           3            3
# ffbcdbad               22            22         22          22           22
# ffbd50d2               15            15         15          15           15
# ffc1f908               17            17         17          17           17
# ffc237d4                1             1          1           1            1
# ffc4ee13                3             3          3           3            3
# ffc8a31e                8             8          8           8            8
# ffc90c32               53            53         53          53           53
# ffc92597                3             3          3           3            3
# ffc98d72                2             2          2           2            2
# ffc993c0                3             3          3           3            3
# ffd000bf                9             9          9           9            9
# ffd2871d               32            32         32          32           32
# ffd5af31               10            10         10          10           10
# ffd7fdf8               10            10         10          10           10
# ffe3b25d               16            16         16          16           16
# ffe63f1b                3             3          3           3            3
# ffe83355               10            10         10          10           10
# ffeb0b1b               37            37         37          37           37
# ffecb712               17            17         17          17           17
# ffee81ed                7             7          7           7            7
# fff169ef                9             9          9           9            9
# fff45f15                8             8          8           8            8
# fff64664               31            31         31          31           31
# fff70c1e                5             5          5           5            5
# fff744ce                3             3          3           3            3
# fff944d5                7             7          7           7            7
# fffc0583               17            17         17          17           17
#
#                  event_code  game_time  title  type  world
# installation_id
# 0001e90f                 10         10     10    10     10
# 000447c4                  5          5      5     5      5
# 0006a69f                 80         80     80    80     80
# 0006c192                 50         50     50    50     50
# 0009a5a9                  7          7      7     7      7
# 0011edc8                 14         14     14    14     14
# 00129856                  9          9      9     9      9
# 0016b7cc                 23         23     23    23     23
# 00195df7                  7          7      7     7      7
# 001d0ed0                 52         52     52    52     52
# 002114ae                  5          5      5     5      5
# 00219589                  3          3      3     3      3
# 00225f67                 25         25     25    25     25
# 00279ac5                 99         99     99    99     99
# 002c8bae                  1          1      1     1      1
# 002db7e3                 75         75     75    75     75
# 003372b0                 57         57     57    57     57
# 0034471d                  1          1      1     1      1
# 0038b87c                 12         12     12    12     12
# 003a6dff                  1          1      1     1      1
# 004adee1                  2          2      2     2      2
# 004c2091                 49         49     49    49     49
# 0050f7a8                  7          7      7     7      7
# 0051064f                 12         12     12    12     12
# 00511b72                  2          2      2     2      2
# 0052394a                  7          7      7     7      7
# 00524526                  1          1      1     1      1
# 005ccc35                  7          7      7     7      7
# 00634433                 11         11     11    11     11
# 00651949                  1          1      1     1      1
# ...                     ...        ...    ...   ...    ...
# ffacf14c                  3          3      3     3      3
# ffb2c879                  1          1      1     1      1
# ffb6a706                  3          3      3     3      3
# ffbcdbad                 22         22     22    22     22
# ffbd50d2                 15         15     15    15     15
# ffc1f908                 17         17     17    17     17
# ffc237d4                  1          1      1     1      1
# ffc4ee13                  3          3      3     3      3
# ffc8a31e                  8          8      8     8      8
# ffc90c32                 53         53     53    53     53
# ffc92597                  3          3      3     3      3
# ffc98d72                  2          2      2     2      2
# ffc993c0                  3          3      3     3      3
# ffd000bf                  9          9      9     9      9
# ffd2871d                 32         32     32    32     32
# ffd5af31                 10         10     10    10     10
# ffd7fdf8                 10         10     10    10     10
# ffe3b25d                 16         16     16    16     16
# ffe63f1b                  3          3      3     3      3
# ffe83355                 10         10     10    10     10
# ffeb0b1b                 37         37     37    37     37
# ffecb712                 17         17     17    17     17
# ffee81ed                  7          7      7     7      7
# fff169ef                  9          9      9     9      9
# fff45f15                  8          8      8     8      8
# fff64664                 31         31     31    31     31
# fff70c1e                  5          5      5     5      5
# fff744ce                  3          3      3     3      3
# fff944d5                  7          7      7     7      7
# fffc0583                 17         17     17    17     17
#
# [17000 rows x 10 columns]

# %% [markdown]
# idem dans le test

# %%
test[(test['event_code'] == 2000)  & (test['type'] == "Assessment")].groupby('installation_id').count()
# Out:
#                  event_id  game_session  timestamp  event_data  event_count  \
# installation_id
# 00abaee7                2             2          2           2            2
# 01242218                6             6          6           6            6
# 017c5718                1             1          1           1            1
# 01a44906                1             1          1           1            1
# 01bc6cb6                1             1          1           1            1
# 02256298                2             2          2           2            2
# 0267757a                1             1          1           1            1
# 027e7ce5               10            10         10          10           10
# 02a29f99                4             4          4           4            4
# 0300c576                1             1          1           1            1
# 03885368                1             1          1           1            1
# 03ac279b                1             1          1           1            1
# 03e33699                4             4          4           4            4
# 048e7427                1             1          1           1            1
# 04a7bc3f                1             1          1           1            1
# 04d31500                2             2          2           2            2
# 0500e23b                1             1          1           1            1
# 0512bf0e                2             2          2           2            2
# 0525589b                1             1          1           1            1
# 05488e26                1             1          1           1            1
# 05771bba                6             6          6           6            6
# 05b82cf5                2             2          2           2            2
# 05e17e19                1             1          1           1            1
# 0617500d               15            15         15          15           15
# 068ae11f                1             1          1           1            1
# 0754f13b                3             3          3           3            3
# 07749e99               10            10         10          10           10
# 08611cc8                2             2          2           2            2
# 08671ec7                1             1          1           1            1
# 0889b0ae                1             1          1           1            1
# ...                   ...           ...        ...         ...          ...
# f6fb106b                4             4          4           4            4
# f7c1b0f3               29            29         29          29           29
# f7ec4dd3                1             1          1           1            1
# f842b8b3                5             5          5           5            5
# f86a6ed4                3             3          3           3            3
# f8d9593e                1             1          1           1            1
# f8dacbde                3             3          3           3            3
# f99be0ba                1             1          1           1            1
# f9dd0fe3                1             1          1           1            1
# fa21f0e4                4             4          4           4            4
# fa537c22                2             2          2           2            2
# fa845dbf                2             2          2           2            2
# faa8c019                1             1          1           1            1
# faee065f                5             5          5           5            5
# fb3e85f5                2             2          2           2            2
# fbe1fea6                1             1          1           1            1
# fc0367c0                9             9          9           9            9
# fc5612b9                1             1          1           1            1
# fca866bc                2             2          2           2            2
# fcff43b4                2             2          2           2            2
# fdfed7eb                4             4          4           4            4
# fe50e0ea                7             7          7           7            7
# fe5f7da8                2             2          2           2            2
# fe8984b5                8             8          8           8            8
# feaa21ac                2             2          2           2            2
# fee254cf                4             4          4           4            4
# ff57e602                2             2          2           2            2
# ffc73fb2                5             5          5           5            5
# ffe00ca8                4             4          4           4            4
# ffe774cc                2             2          2           2            2
#
#                  event_code  game_time  title  type  world
# installation_id
# 00abaee7                  2          2      2     2      2
# 01242218                  6          6      6     6      6
# 017c5718                  1          1      1     1      1
# 01a44906                  1          1      1     1      1
# 01bc6cb6                  1          1      1     1      1
# 02256298                  2          2      2     2      2
# 0267757a                  1          1      1     1      1
# 027e7ce5                 10         10     10    10     10
# 02a29f99                  4          4      4     4      4
# 0300c576                  1          1      1     1      1
# 03885368                  1          1      1     1      1
# 03ac279b                  1          1      1     1      1
# 03e33699                  4          4      4     4      4
# 048e7427                  1          1      1     1      1
# 04a7bc3f                  1          1      1     1      1
# 04d31500                  2          2      2     2      2
# 0500e23b                  1          1      1     1      1
# 0512bf0e                  2          2      2     2      2
# 0525589b                  1          1      1     1      1
# 05488e26                  1          1      1     1      1
# 05771bba                  6          6      6     6      6
# 05b82cf5                  2          2      2     2      2
# 05e17e19                  1          1      1     1      1
# 0617500d                 15         15     15    15     15
# 068ae11f                  1          1      1     1      1
# 0754f13b                  3          3      3     3      3
# 07749e99                 10         10     10    10     10
# 08611cc8                  2          2      2     2      2
# 08671ec7                  1          1      1     1      1
# 0889b0ae                  1          1      1     1      1
# ...                     ...        ...    ...   ...    ...
# f6fb106b                  4          4      4     4      4
# f7c1b0f3                 29         29     29    29     29
# f7ec4dd3                  1          1      1     1      1
# f842b8b3                  5          5      5     5      5
# f86a6ed4                  3          3      3     3      3
# f8d9593e                  1          1      1     1      1
# f8dacbde                  3          3      3     3      3
# f99be0ba                  1          1      1     1      1
# f9dd0fe3                  1          1      1     1      1
# fa21f0e4                  4          4      4     4      4
# fa537c22                  2          2      2     2      2
# fa845dbf                  2          2      2     2      2
# faa8c019                  1          1      1     1      1
# faee065f                  5          5      5     5      5
# fb3e85f5                  2          2      2     2      2
# fbe1fea6                  1          1      1     1      1
# fc0367c0                  9          9      9     9      9
# fc5612b9                  1          1      1     1      1
# fca866bc                  2          2      2     2      2
# fcff43b4                  2          2      2     2      2
# fdfed7eb                  4          4      4     4      4
# fe50e0ea                  7          7      7     7      7
# fe5f7da8                  2          2      2     2      2
# fe8984b5                  8          8      8     8      8
# feaa21ac                  2          2      2     2      2
# fee254cf                  4          4      4     4      4
# ff57e602                  2          2      2     2      2
# ffc73fb2                  5          5      5     5      5
# ffe00ca8                  4          4      4     4      4
# ffe774cc                  2          2      2     2      2
#
# [1000 rows x 10 columns]

# %% [markdown]
# On remarque qu'à la fois dans le train et dans le test, il esxiste des enfants n'ayant tenté un assessment qu'une seule fois donc pas d'historique pour ces enfants.

# %% [markdown]
# Il faut reproduire sur le train la structure du test cad pour chaque installation_id, tronquer le déroulé du dernier assessemnt. (C'est bien le dernier qui a été tronqué dans le test et pas un assessment random selon une certaine loi).
